# %% [markdown]
# # Project Description

# %% [markdown]
# This is a shopping program that is based off a videogame called Stardew Valley. To keep it simple, the goal of Stardew Valley is to farm and make money. Therefore, this code allows you to shop for farming seeds.
#
# This shopping program is mainly function driven and is navigated through user inputs.
#
# These are the features included in this shopping program
# * The items are split into four categories.
# * The ability to add a desired amount of seed into the shopping cart
# * The ability to type however you want as long as the spelling and spacing is correct and the program would still be able to detect which item you want.
# * The ability to remove certain amount of a specific item without having to completely remove the item altogether.
# * The ability to check what is in your shopping cart along with the total price of each item.
# * The ability to clear cart after checkout

# %% [markdown]
# ## Project Code
#
# If it makes sense for your project, you can have code and outputs here in the notebook as well.

# %%
#import files
from my_module.functions import Main_Menu

# %%
#start shopping
Main_Menu()
# Out:
# Menu Options
#
# Pick a number:
#         1. View seeds
#         2. Add seeds to cart
#         3. Remove seed from cart
#         4. View cart
#         5. Checkout cart
#         6. Exit
#
# Page number: 1
# Choose Season
#         Pick a number:
#         1. Spring
#         2. Summer
#         3. Fall
#         4. Winter
#         5. Go Back
#
# Page number: 2
# ---- item : $ -----
#  blueberry seeds : 80
#  corn seeds : 150
#  melon seeds : 80
#  pepper seeds : 40
#  poppy seeds : 100
#  sadish seeds : 40
#  red cabbage seeds : 100
#  spangle seeds : 50
#  sunflower seeds : 200
#  starfruit seeds : 400
#  tomato seeds : 50
#  wheat seeds : 10
# ---------
# Choose Season
#         Pick a number:
#         1. Spring
#         2. Summer
#         3. Fall
#         4. Winter
#         5. Go Back
#
# Page number: 1
# ---- item : $ -----
#  cauliflower seeds : 80
#  garlic seeds : 40
#  jazz seeds : 30
#  kale seeds : 70
#  parsnip seeds : 20
#  potato seeds : 50
# ...

# %% [markdown]
# # Extra Credit (*optional*)
#
# Replace all of this text with a brief explanation (~3 sentences) of:
# 1. I had very little Python experience before taking this course. This little experience just consisted of being able to print and calculate integers. I have done a little bit of HTML, which is just creating a website.
#
#
# 2. My project went above and beyong the requirements because I used more than 3 functions and I did a bit of changing the font style of the printed out text. I challenged myself to learn something new because besides creating a chatbot, which was required in our assignment, I never created anything that was user interactive. I learned how the input() program worked and I had to organize each function to make sure it made sense once the user inputted a specific number of word. I also learned about what import sys does.
